# %% [markdown]
# ![map.JPG](attachment:map.JPG)

# %%
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %% [markdown]
# # Uniform Cost Search

# %%
from queue import PriorityQueue


def ucs(startingNode, destinationNode):
    expanded = [] 
    frontier = PriorityQueue()

    snode = (0,startingNode,[startingNode]) 
    frontier.put(snode)
    
    while not frontier.empty():
        unode = frontier.get() 
        u = unode[1] 
        if u == destinationNode:         
            print(unode)
            print(expanded)
            return unode[2] 
        expanded.append(u)
        for v in romanian_map[u].keys():            
            if v not in expanded:
                cost = unode[0] + romanian_map[u][v]
                path = unode[2] + [v]
                frontier.put((cost,v,path))
                print(v+ ", Cost: " +str(cost))
    print('Failed')

# %%
ucs('Sibiu', 'Urziceni')
# Out:
# Arad, Cost: 140
# Oradea, Cost: 151
# Fagaras, Cost: 99
# Rimnicu, Cost: 80
# Craiova, Cost: 226
# Pitesti, Cost: 177
# Bucharest, Cost: 310
# Zerind, Cost: 215
# Timisoara, Cost: 258
# Zerind, Cost: 222
# Craiova, Cost: 315
# Bucharest, Cost: 278
# Drobeta, Cost: 346
# Lugoj, Cost: 369
# Giurgiu, Cost: 368
# Urziceni, Cost: 363
# Giurgiu, Cost: 400
# Urziceni, Cost: 395
# Drobeta, Cost: 435
# Mehadia, Cost: 421
# (363, 'Urziceni', ['Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest', 'Urziceni'])
# ['Sibiu', 'Rimnicu', 'Fagaras', 'Arad', 'Oradea', 'Pitesti', 'Zerind', 'Zerind', 'Craiova', 'Timisoara', 'Bucharest', 'Bucharest', 'Craiova', 'Drobeta']
# ['Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest', 'Urziceni']

# %% [markdown]
# ![ucs.PNG](attachment:ucs.PNG)

# %% [markdown]
# # Greedy Best First Search

# %%
h = {'Arad': 366,'Zerind':  374,'Oradea': 380,'Sibiu': 253,
    'Timisoara': 329,'Lugoj': 244,'Mehadia': 241,'Drobeta': 242,
    'Craiova': 160,'Rimnicu': 193,'Fagaras': 176,'Pitesti': 100,
    'Bucharest': 0,'Giurgiu': 77,'Urziceni': 80,'Hirsova': 151,
    'Eforie': 161,'Vaslui': 199,'Iasi': 226,'Neamt': 234
}

# %%
from queue import PriorityQueue

def gbfs(startingNode, destinationNode):
    expanded = [] 
    frontier = PriorityQueue()

    snode = (h[startingNode],startingNode,[startingNode],0)
    frontier.put(snode)

    while not frontier.empty():
        unode = frontier.get() 
        u = unode[1]
        
        if u== destinationNode:            
            print(unode)
            print(expanded)
            return unode[2] 
        expanded.append(u)
        for v in romanian_map[u].keys():            
            if v not in expanded:
                cost = unode[3] + romanian_map[u][v]
                path = unode[2]+[v]
                frontier.put((h[v],v,path, cost))   
    print('Failed')

# %%
gbfs('Lugoj', 'Bucharest')
# Out:
# (0, 'Bucharest', ['Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest'], 504)
# ['Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti']
# ['Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']

# %% [markdown]
# ![gbfs.PNG](attachment:gbfs.PNG)

# %% [markdown]
# # A*

# %%
from queue import PriorityQueue

def A_star(startingNode, destinationNode):
    expanded = [] 
    frontier = PriorityQueue()

    snode = (0+h[startingNode],startingNode,[startingNode],0) 
    frontier.put(snode)

    while not frontier.empty():
        unode = frontier.get() 
        u = unode[1]
        
        if u== destinationNode:           
            print(unode)
            print(expanded)
            return unode[2] 
        expanded.append(u)
        for v in romanian_map[u].keys():            
            if v not in expanded:
                cost = unode[3] + romanian_map[u][v]
                path = unode[2]+[v]
                frontier.put((cost+h[v],v,path, cost))   
    print('Failed')

# %%
A_star('Sibiu', 'Bucharest')
# Out:
# (278, 'Bucharest', ['Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest'], 278)
# ['Sibiu', 'Rimnicu', 'Fagaras', 'Pitesti']
# ['Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']

# %% [markdown]
# ![Astar..PNG](attachment:Astar..PNG)
